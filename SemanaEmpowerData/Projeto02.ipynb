# %% [markdown]
# # Projeto 02

# %%
#importando bibliotecas
import yfinance

# %%
dados = yfinance.Ticker('PETR4.SA').history(start='2024-01-01', end='2024-12-31')
fechamento = dados.Close
fechamento.plot()
# Out:
# <Axes: xlabel='Date'>
